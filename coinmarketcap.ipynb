# %%
from cryptocmd import CmcScraper
import pandas as pd

#scraper = CmcScraper('ETH')    #get all data

scraper = CmcScraper('ETH', '12-04-2016', '13-04-2021')

headers, data = scraper.get_data()

xrp_json_data = scraper.get_data("json")

scraper.export_csv('eth_all_time.csv')

df = scraper.get_dataframe()

df.set_index('Date', inplace=True)

# %%
df
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2021-04-12  2157.361728  2199.718673  2110.368968  2139.353196  2.172794e+10
# 2021-04-11  2136.156983  2165.191500  2119.865673  2157.657037  1.969284e+10
# 2021-04-10  2071.111560  2196.996253  2062.787516  2135.942201  2.498624e+10
# 2021-04-09  2088.772299  2102.873732  2055.163357  2072.108876  1.981247e+10
# 2021-04-08  1969.133209  2091.516392  1959.079475  2088.573651  2.531296e+10
# ...                 ...          ...          ...          ...           ...
# 2016-04-16     8.235880     8.649760     8.114440     8.609500  9.888460e+06
# 2016-04-15     8.386060     8.616200     8.097330     8.242780  1.217900e+07
# 2016-04-14     8.075170     8.757040     8.021520     8.387240  1.359070e+07
# 2016-04-13     7.441360     8.719770     7.069220     8.044420  3.140330e+07
# 2016-04-12     8.639470     8.639470     7.154160     7.442310  2.319010e+07
#
#               Market Cap
# Date
# 2021-04-12  2.469753e+11
# 2021-04-11  2.490591e+11
# 2021-04-10  2.465234e+11
# 2021-04-09  2.391279e+11
# 2021-04-08  2.410001e+11
# ...                  ...
# 2016-04-16  6.813837e+08
# 2016-04-15  6.520998e+08
# 2016-04-14  6.632624e+08
# 2016-04-13  6.358995e+08
# 2016-04-12  5.880692e+08
#
# [1827 rows x 6 columns]

# %%
df['Close'].plot(figsize = (12,7))
# Out:
# <AxesSubplot:xlabel='Date'>
